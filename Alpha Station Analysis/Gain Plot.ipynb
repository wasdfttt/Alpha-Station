# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
# %matplotlib inline
"""
NOTE: Any data that is commented out is either old data that is wrong from a previous version of the gain code or was used for testing purposes
      Final plots are uploaded in their respective folders.
"""
# Out:
# '\nNOTE: Any data that is commented out is either old data that is wrong from a previous version of the gain code or was used for testing purposes\n      Final plots are uploaded in their respective folders.\n'

# %%
angles = [0, 15, 22, 30, 37, 45]
colours = cm.rainbow(np.linspace(0,1,7))
"""
Old, inaccurate data from previous versions of gain code
"""
#Old data
#W14_200VMeans = [1.32478, 1.27760, 1.56997, 1.47850, 1.37083, 1.27879]
W14_200VMeans = [1.32915, 1.28001, 1.57317, 1.48135, 1.37367, 1.28147]
#W14_200Vrms = [0.12283, 0.11951, 0.12738, 0.13011, 0.11983, 0.10608]
W14_200Vrms = [0.12282, 0.11956, 0.12733, 0.13005, 0.11985, 0.10619]
#W14_300VMeans = [1.41070, 1.34717, 1.61753, 1.53607, 1.39654, 1.29349]
W14_300VMeans = [1.41308, 1.34939, 1.62005, 1.53858, 1.39966, 1.29691]
#W14_300Vrms = [0.16115, 0.15262, 0.16351, 0.16957, 0.15270, 0.13640]
W14_300Vrms = [0.16125, 0.15279, 0.16367, 0.16979, 0.15284, 0.13649]

plt.errorbar(angles, W14_200VMeans, W14_200Vrms, capsize = 5, capthick = 1.5, color = colours[0], label = '200V', marker = 'o')
plt.errorbar(angles, W14_300VMeans, W14_300Vrms, capsize = 5, capthick = 1.5, color = colours[1], label = '300V', marker = 'o')
plt.axis([-5, 50, 1, 2])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('W14 Gain as Function of Angle')
plt.legend(loc = 'lower left', fontsize = 12)
plt.rcParams['figure.figsize'] = [6.4, 4.8]
plt.rcParams['figure.dpi'] = 100
plt.show()

# %%
"""
Old, inaccurate data from previous versions of gain code
"""

W14_200VMeans = [2.10438, 1.96095, 2.61684, 2.45326, 2.22440, 1.99175]
W14_200Vrms = [0.21223, 0.20101, 0.22922, 0.23630, 0.21446, 0.18792]
W14_200VMeans2 = [2.20293, 2.03493, 2.58911, 2.45638, 2.18180, 1.92337]
W14_200Vrms2 = [0.23539, 0.21002, 0.22605, 0.24290, 0.21354, 0.18041]
W14_300VMeans = [1.82170, 1.68277, 2.14105, 2.03129, 1.80423, 1.59052]
W14_300Vrms = [0.22093, 0.19870, 0.22368, 0.23222, 0.20469, 0.17488]
#Old data
plt.errorbar(angles, W14_200VMeans, W14_200Vrms, capsize = 5, capthick = 1.5, color = colours[0], label = '200V (Pin 150V)', marker = 'o')
plt.errorbar(angles, W14_200VMeans2, W14_200Vrms2, capsize = 5, capthick = 1.5, color = colours[1], label = '300V (Pin 150V)', marker = 'o')
plt.errorbar(angles, W14_300VMeans, W14_300Vrms, capsize = 5, capthick = 1.5, color = colours[2], label = '300V (Pin 250V)', marker = 'o')
plt.axis([-5, 50, 1, 3])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('W14 Gain as Function of Angle')
plt.legend(loc = 'lower left', fontsize = 12)
plt.show()

# %%
"""
Correct New Data for W14
"""
W14_200VMeans = [1.71607, 1.5936, 2.12481, 1.99737, 1.81548, 1.62136]#[1.71154, 1.58949, 2.11933, 1.99224, 1.81079, 1.61715]
W14_200Vrms = [0.00236, 0.00221, 0.00271, 0.00268, 0.00245, 0.00215]#[0.19782, 0.18612, 0.22114, 0.22274, 0.20241, 0.17796]
W14_300VMeans = [1.79057, 1.652, 2.09288, 1.9889, 1.77346, 1.55969]#[1.78591, 1.64773, 2.08749, 1.98383, 1.76886, 1.55564]
W14_300Vrms = [0.00254, 0.0023, 0.00267, 0.00272, 0.00241, 0.00206]#[0.21584, 0.19391, 0.21697, 0.22593, 0.19989, 0.17031]

plt.errorbar(angles, W14_200VMeans, W14_200Vrms, capsize = 5, capthick = 1.5, color = colours[0], label = '200V', marker = 'o')
plt.errorbar(angles, W14_300VMeans, W14_300Vrms, capsize = 5, capthick = 1.5, color = colours[1], label = '300V', marker = 'o')
#plt.errorbar(angles, W14_300VMeans2, W14_300Vrms2, capsize = 5, capthick = 1.5, color = colours[2], label = '300V (Pin 250V)', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('W14 Gain as Function of Angle')
plt.legend(loc = 'lower left', fontsize = 12)
plt.show()

# %%
"""
#Old, inaccurate data from previous versions of gain code
W11_300VMeans = [2.60389, 2.65042, 2.65671, 2.62634, 2.52939, 2.53668]
W11_300Vrms = [0.24491, 0.22940, 0.23451, 0.23097, 0.24796, 0.25437]
W11_300VMeans2 = [2.15327, 2.19175, 2.19695, 2.17193, 2.09167, 2.09769] #W14 Pin 250V
W11_300Vrms2 = [0.23723, 0.22759, 0.23128, 0.22804, 0.23758, 0.24235]
W11_400VMeans = [2.15124, 2.20668, 2.21193, 2.18730, 2.11023, 2.14238]
W11_400Vrms = [0.23970, 0.23038, 0.23699, 0.23424, 0.25038, 0.26612]
"""


"""
Correct data for W11
"""
W11_300VMeans = [2.07087, 2.10786, 2.11285, 2.08865, 2.01168, 2.01736]#[2.07084, 2.10785, 2.11281, 2.08865, 2.01165, 2.01740]
W11_300Vrms = [0.00278, 0.00268, 0.00271, 0.00266, 0.00272, 0.00278]#[0.23485, 0.22614, 0.22946, 0.22637, 0.23494, 0.23928]
W11_400VMeans = [2.07671, 2.12527, 2.13062, 2.10678, 2.0326, 2.06389]#[2.07669, 2.12527, 2.13072, 2.10677, 2.03259, 2.06388]
W11_400Vrms = [0.00281, 0.00271, 0.00277, 0.00273, 0.00284, 0.00302]#[0.23735, 0.22867, 0.23469, 0.23218, 0.24656, 0.26154]

plt.errorbar(angles, W11_300VMeans, capsize = 5, capthick = 1.5, color = colours[0], label = '300V', marker = 'o')
plt.errorbar(angles, W11_400VMeans, capsize = 5, capthick = 1.5, color = colours[1], label = '400V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('W11 Gain as Function of Angle')
plt.legend(loc = 'lower left', fontsize = 12)
plt.show()

# %%
"""
Correct data for W8
"""

#W8_200VMeans = [2.06540, 2.11618, 2.08723, 2.06948, 2.01325, 2.02133]
#W8_200Vrms = [0.21857, 0.21621, 0.20597, 0.20513, 0.21457, 0.21939]
#W8_300VMeans = [2.13784, 2.13597, 2.15049, 2.10632, 2.08419, 2.11802]
#W8_300Vrms = [0.23204, 0.21594, 0.21590, 0.22289, 0.24187, 0.25408]
W8_200VMeans = [2.04447, 2.09236, 2.06457, 2.04696, 1.99006, 1.99789]#[2.04447, 2.09236, 2.06566, 2.04696, 1.99006, 1.99847]
W8_200Vrms = [0.00567, 0.00557, 0.00521, 0.00511, 0.00548, 0.00577]#[0.21829, 0.21836, 0.20792, 0.20529, 0.21180, 0.21739]
W8_300VMeans = [2.11772, 2.1161, 2.13095, 2.08556, 2.06432, 2.09817]#[2.11183, 2.11021, 2.12422, 2.07976, 2.05858, 2.09233]
W8_300Vrms = [0.00607, 0.00548, 0.00559, 0.00591, 0.00652, 0.00704]#[0.23116, 0.21618, 0.21630, 0.22483, 0.24152, 0.25362]

plt.plot(angles, W8_200VMeans, color = colours[0], label = '200V', marker = 'o')
#plt.errorbar(angles, W8_200VMeans, W8_200Vrms, capsize = 5, capthick = 1.5, color = colours[0], label = '200V', marker = 'o')
plt.plot(angles, W8_300VMeans, color = colours[1], label = '300V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('W8 Gain as Function of Angle')
plt.legend(loc = 'lower left', fontsize = 12)
plt.show()

# %%
W1_180VMeans = [1.24501, 2.10066, 1.57338, 1.74436, 1.20164, 1.37198]#[1.25141, 2.11146, 1.58148, 1.75334, 1.20641, 1.37908]
W1_180Vrms = [0.00177, 0.00288, 0.00209, 0.00232, 0.0016, 0.0019]#[0.15471, 0.24756, 0.17968, 0.19787, 0.14386, 0.16443]
W1_240VMeans = [1.62948, 2.17069, 1.62536, 1.82599, 1.28161, 1.44928]#[1.63576, 2.17915, 1.63167, 1.83308, 1.45651]
W1_240Vrms = [0.00229, 0.00296, 0.00219, 0.00248, 0.00186, 0.00214]#[0.24901, 0.25488, 0.18849, 0.21360, 0.19002]
angles = [0, 15, 22.5, 30, 37.5, 45]

plt.plot(angles, W1_180VMeans, color = colours[0], label = '180V', marker = 'o')
plt.plot(angles, W1_240VMeans, color = colours[1], label = '240V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('W1 Gain as Function of Angle')
plt.legend(loc = 'lower left', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
W9_200VMeans = [2.14733, 2.17144, 2.1175, 2.07734, 2.05911, 2.01283]#[2.14733, 2.17142, 2.11756, 2.07734, 2.05911, 2.01285]
W9_200Vrms = [0.00321, 0.003, 0.00293, 0.00316, 0.00314, 0.00349]#[0.22856, 0.21533, 0.21192, 0.22765, 0.22605, 0.24731]
W9_300VMeans = [2.16777, 2.19094, 2.13829, 2.10983, 2.10684, 2.08344]#[2.16174, 2.18485, 2.13226, 2.10401, 2.10097, 2.07764]
W9_300Vrms = [0.00334, 0.00313, 0.0031, 0.00332, 0.00363, 0.0043]#[0.23593, 0.22359, 0.223, 0.23955, 0.25806, 0.30056]

plt.errorbar(angles, W9_200VMeans, color = colours[0], label = '200V', marker = 'o')
plt.errorbar(angles, W9_300VMeans, color = colours[1], label = '300V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('W9 Gain as Function of Angle')
plt.legend(loc = 'lower left', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
#BNL_200um_300VMeans = [1.42401, 0.87952, 1.23006, 1.44075]
#BNL_200um_300Vrms = [0.15327, 0.54248, 0.62770, 0.16447]
#BNL_200um_450VMeans  = [1.82279, 1.79352, 1.22688, 1.81982]
#BNL_200um_450Vrms = [0.20158, 0.27025, 1.58285, 0.21188]
BNL_200um_300VMeans = [2.04591, 1.22884, 1.19857, 1.28335, 2.00649, 1.13163]
BNL_200um_300Vrms = [0.25890, 0.52718, 0.55313, 0.77525, 0.27994, 0.55771]
BNL_200um_450VMeans = [1.91140, 1.91389, 1.89613, 0.54778, 1.89663, 1.92641]
BNL_200um_450Vrms = [0.22631, 0.22717, 0.24748, 2.17536, 0.23700, 0.23433]
angles = [0, 0, 15, 22, 30, 37]
[1.82279, 1.83656, 1.79352, 1.22688, 1.81982, 1.82006]
[0.20158, 0.20488, 0.27025, 1.58285, 0.21188, 0.25842]

plt.errorbar(angles, BNL_200um_300VMeans, BNL_200um_300Vrms, capsize = 5, capthick = 1.5, color = colours[0], label = '300V', marker = 'o')
plt.errorbar(angles, BNL_200um_450VMeans, BNL_200um_450Vrms, capsize = 5, capthick = 1.5, color = colours[1], label = '450V', marker = 'o')
plt.axis([-5, 50, 0, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('BNL 200 μm Gain as Function of Angle')
plt.legend(loc = 'lower left', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
BNL_200um_300VMeans = [2.01028, 2.00686, 2.05382, 2.0204, 2.05743]
BNL_200um_300Vrms = [0.26367, 0.26172, 0.25109, 0.26687, 0.26344]
BNL_200um_450VMeans = [1.8919, 1.90282, 1.92834, 1.92613, 1.95027]
BNL_200um_450Vrms = [0.24265, 0.24122, 0.25711, 0.23578, 0.24176]
BNL_200um_600VMeans = [1.88474, 1.87333, 1.82872, 1.87356, 1.90972]
BNL_200um_600Vrms = [0.24735, 0.2443, 0.26068, 0.24652, 0.24573]

#BNL_200um_250VBackMeans = [7.67408, 7.82446]
#BNL_200um_300VBackMeans = [7.43345, 7.75236]
#BNL_200um_390VBackMeans = [6.85520, 7.67585]
pin250V = .149675
BNL_200um_300VBackMeans = [1.16433/pin250V]
BNL_200um_350VBackMeans = [1.16371/pin250V]
BNL_200um_400VBackMeans = [1.14687/pin250V]
BNL_200um_450VBackMeans = [1.20764/pin250V]


angles = [0, 15, 22, 30, 37]
plt.errorbar(angles, BNL_200um_300VMeans, BNL_200um_300Vrms, capsize = 5, capthick = 1.5, color = colours[0], label = '300V', marker = 'o')
plt.errorbar(angles, BNL_200um_450VMeans, BNL_200um_450Vrms, capsize = 5, capthick = 1.5, color = colours[1], label = '450V', marker = 'o')
plt.errorbar(angles, BNL_200um_600VMeans, BNL_200um_600Vrms, capsize = 5, capthick = 1.5, color = colours[2], label = '600V', marker = 'o')
angles = [0]
plt.plot(angles, BNL_200um_300VBackMeans, color = colours[3], label = '300V Back', marker = 'o')
plt.plot(angles, BNL_200um_350VBackMeans, color = colours[4], label = '350V Back', marker = 'o')
plt.plot(angles, BNL_200um_400VBackMeans, color = colours[5], label = '400V Back', marker = 'o')
plt.plot(angles, BNL_200um_450VBackMeans, color = colours[6], label = '450V Back', marker = 'o')
plt.axis([-5, 50, 1, 8.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('BNL 200 μm Gain as Function of Angle')
plt.legend(loc = 'upper right', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
pin250V = .149675
BNL_200um_425VPressure = [2.32357, 2.89935, 2.0401, 1.90973, 1.64872, 1.45182, 1.28106, 1.06105]
BNL_200um_425VPressurerms = [1.18572, 2.14703, .9018, .89995, .70006, .63246, .52622, .41572]
for i in range(len(BNL_200um_425VPressure)):
    BNL_200um_425VPressure[i]/=pin250V
    BNL_200um_425VPressurerms[i]*=3

colours = cm.rainbow(np.linspace(0,1,8))
pressures = [100, 200, 300, 400, 500, 600, 700, 800]
plt.errorbar(pressures, BNL_200um_425VPressure, BNL_200um_425VPressurerms, capsize = 5, capthick = 1.5, color = 'k', label = '425V', marker = 'o')
plt.axis([0, 900, 5, 30])
plt.xlabel('Pressure (mtorr)')
plt.ylabel('Gain')
plt.title('BNL 200 μm Gain as Function of Angle')
plt.legend(loc = 'upper right', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
W5_140VMeans = [2.22946, 2.16829, 2.14238]
W5_190VMeans = [2.21342, 2.18496, 2.16058]

colours = cm.rainbow(np.linspace(0,1,3))
angles = [0, 15, 22.5]
plt.plot(angles, W5_140VMeans, color = colours[0], label = '140V', marker = 'o')
plt.plot(angles, W5_190VMeans, color = colours[2], label = '190V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('FBK W5 Gain as Function of Angle')
plt.legend(loc = 'upper right', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
W16_160VMeans = [1.48174, 1.4719]
W16_210VMeans = [1.52881, 1.51269]
W16_100VMeans = [2.32265, 2.29654]
W16_140VMeans = [2.29828, 2.33718]
W16_190VMeans = [2.05326, 2.40107]

colours = cm.rainbow(np.linspace(0,1,5))
angles = [0, 15]
plt.plot(angles, W16_160VMeans, color = colours[0], label = '160V', marker = 'o')
plt.plot(angles, W16_210VMeans, color = colours[1], label = '210V', marker = 'o')
plt.plot(angles, W16_100VMeans, color = colours[2], label = 'Redo 100V', marker = 'o')
plt.plot(angles, W16_140VMeans, color = colours[3], label = 'Redo 140V', marker = 'o')
plt.plot(angles, W16_190VMeans, color = colours[4], label = 'Redo 190V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('FBK W16 Gain as Function of Angle')
plt.legend(loc = 'upper right', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
W18_140VMeans = [2.33891, 2.35104]
W18_190VMeans = [2.41552, 2.41654]

colours = cm.rainbow(np.linspace(0,1,7))
angles = [0, 15]
plt.plot(angles, W18_140VMeans, color = colours[0], label = '140V', marker = 'o')
plt.plot(angles, W18_190VMeans, color = colours[1], label = '190V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('FBK W18 Gain as Function of Angle')
plt.legend(loc = 'upper right', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
W9_new_150VMeans = [2.21543, 2.24322]
W9_new_200VMeans = [2.24992, 2.2572]

colours = cm.rainbow(np.linspace(0,1,7))
angles = [0, 15]
plt.plot(angles, W9_new_150VMeans, color = colours[0], label = '150V', marker = 'o')
plt.plot(angles, W9_new_200VMeans, color = colours[1], label = '200V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('FBK New W9 Gain as Function of Angle')
plt.legend(loc = 'upper right', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
colours = cm.rainbow(np.linspace(0,1,11))
angles = [0, 15, 22.5]
plt.plot(angles, W5_140VMeans, color = colours[0], label = 'W5 140V', marker = 'o')
plt.plot(angles, W5_190VMeans, color = colours[1], label = 'W5 190V', marker = 'o')
angles = [0, 15]

plt.plot(angles, W9_new_150VMeans, color=colours[2], label = 'W9 New 150V', marker = 'o')
plt.plot(angles, W9_new_200VMeans, color=colours[3], label = 'W9 New 200V', marker = 'o')
plt.plot(angles, W16_160VMeans, color = colours[4], label = 'W16 160V', marker = 'o')
plt.plot(angles, W16_210VMeans, color = colours[5], label = 'W16 210V', marker = 'o')
plt.plot(angles, W18_140VMeans, color = colours[6], label = 'W18 140V', marker = 'o')
plt.plot(angles, W18_190VMeans, color = colours[7], label = 'W18 190V', marker = 'o')
plt.plot(angles, W16_100VMeans, color = colours[8], label = 'W16 Redo 100V', marker = 'o')
plt.plot(angles, W16_140VMeans, color = colours[9], label = 'W16 Redo 140V', marker = 'o')
plt.plot(angles, W16_190VMeans, color = colours[10], label = 'W16 Redo 190V', marker = 'o')
angles = [0, 15, 22.5, 30, 37.5, 45]
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('FBK W5, W9, W16, W18 Gain as Function of Angle')
plt.legend(loc = 'upper right', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
colours = cm.rainbow(np.linspace(0,1,7))
angles = [0, 15, 22.5]
plt.plot(angles, W5_190VMeans, color = colours[0], label = 'W5 190V', marker = 'o')
angles = [0, 15]
plt.plot(angles, W16_210VMeans, color = colours[1], label = 'W16 210V', marker = 'o')
plt.plot(angles, W18_190VMeans, color = colours[2], label = 'W18 190V', marker = 'o')
plt.plot(angles, W16_140VMeans, color = colours[3], label = 'W16 Redo 140V', marker = 'o')
plt.plot(angles, W16_190VMeans, color = colours[4], label = 'W16 Redo 190V', marker = 'o')
plt.plot(angles, W9_new_200VMeans, color=colours[5], label = 'W9 New 200V', marker = 'o')
angles = [0, 15, 22.5, 30, 37.5, 45]
plt.plot(angles, W1_240VMeans, color = colours[6], label = 'W1 240V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('FBK New Production Gain vs W1 as Function of Angle')
plt.legend(loc = 'upper right', fontsize = 12)
angles = [0, 15, 22, 30, 37, 45]
plt.show()

# %%
colours = cm.rainbow(np.linspace(0,1,10))
angles = [0, 15, 22.5, 30, 37.5, 45]
plt.plot(angles, W1_180VMeans, color = colours[0], label = 'W1 180V', marker = 'o')
plt.plot(angles, W1_240VMeans, color = colours[1], label = 'W1 240V', marker = 'o')
plt.plot(angles, W8_200VMeans, color = colours[2], label = 'W8 200V', marker = 'o')
plt.plot(angles, W8_300VMeans, color = colours[3], label = 'W8 300V', marker = 'o')
plt.plot(angles, W9_200VMeans, color = colours[4], label = 'W9 200V', marker = 'o')
plt.plot(angles, W9_300VMeans, color = colours[5], label = 'W9 300V', marker = 'o')
plt.plot(angles, W11_300VMeans, color = colours[6], label = 'W11 300V', marker = 'o')
plt.plot(angles, W11_400VMeans, color = colours[7], label = 'W11 400V', marker = 'o')
plt.plot(angles, W14_200VMeans, color = colours[8], label = 'W14 200V', marker = 'o')
plt.plot(angles, W14_300VMeans, color = colours[9], label = 'W14 300V', marker = 'o')
plt.axis([-5, 50, 1, 2.5])
plt.xlabel('Angle (deg)')
plt.ylabel('Gain')
plt.title('FBK Previous Production Gain as Function of Angle')
plt.legend(loc = 'lower left', fontsize = 12)
plt.rcParams['figure.figsize'] = (12, 8)
angles = [0, 15, 22, 30, 37, 45]
plt.show()
plt.rcParams['figure.figsize'] = (6.4, 4.8)
